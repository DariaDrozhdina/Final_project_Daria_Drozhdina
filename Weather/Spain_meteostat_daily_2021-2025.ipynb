# %% [markdown]
# ## Daily weather data for Spain

# %%
import requests
import pandas as pd
import time

API_KEY = 'f0b507b810mshbfc5fe89dc7b720p1423aajsn26a2f19b52a3'
HEADERS = {
    "X-RapidAPI-Key": API_KEY,
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

STATIONS = {
    "08025": "Bilbao",
    "08042": "Santiago de Compostela",
    "08284": "Valencia",
    "08181": "Barcelona",
    "08391": "Seville",
    "08482": "Malaga",
    "08221": "Madrid",
    "08160": "Zaragoza"
}

all_records = []

for station_id, station_name in STATIONS.items():
    response = requests.get(
        "https://meteostat.p.rapidapi.com/stations/monthly",
        headers=HEADERS,
        params={"station": station_id, "start": "2021-01-01", "end": "2025-12-31"}
    )
    data = response.json().get("data", [])

    for row in data:
        row["station_id"]   = station_id
        row["station_name"] = station_name
        all_records.append(row)

    print(f"✅ {station_name}: {len(data)} months fetched")
    time.sleep(0.3)

df = pd.DataFrame(all_records)

print(df)
df.to_csv("spain_weather.csv", index=False)
# Out:
# ✅ Bilbao: 60 months fetched
# ✅ Santiago de Compostela: 60 months fetched
# ✅ Valencia: 60 months fetched
# ✅ Barcelona: 60 months fetched
# ✅ Seville: 60 months fetched
# ✅ Malaga: 60 months fetched
# ✅ Madrid: 60 months fetched
# ✅ Zaragoza: 60 months fetched
#                     date station_id station_name     tsun  tsun_hours
# 0    2021-01-01 00:00:00      08025       Bilbao   2640.0        44.0
# 1    2021-02-01 00:00:00      08025       Bilbao   4020.0        67.0
# 2    2021-03-01 00:00:00      08025       Bilbao   8520.0       142.0
# 3    2021-04-01 00:00:00      08025       Bilbao   8820.0       147.0
# 4    2021-05-01 00:00:00      08025       Bilbao  10260.0       171.0
# ..                   ...        ...          ...      ...         ...
# 475  2025-08-01 00:00:00      08160     Zaragoza  19560.0       326.0
# 476  2025-09-01 00:00:00      08160     Zaragoza  17100.0       285.0
# 477  2025-10-01 00:00:00      08160     Zaragoza  14760.0       246.0
# 478  2025-11-01 00:00:00      08160     Zaragoza  10620.0       177.0
# 479  2025-12-01 00:00:00      08160     Zaragoza   6660.0       111.0
#
# [480 rows x 5 columns]
