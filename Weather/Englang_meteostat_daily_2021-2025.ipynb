# %% [markdown]
# ## Daily weather data for England

# %%
import requests
import pandas as pd
import time

API_KEY = 'f0b507b810mshbfc5fe89dc7b720p1423aajsn26a2f19b52a3'
HEADERS = {
    "X-RapidAPI-Key": API_KEY,
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

STATIONS = {
    "03245": "Newcastle upon Tyne",
    "03262": "Sunderland",
    "03263": "Middlesbrough",
    "03347": "Leeds",
    "03334": "Manchester",
    "03266": "York",
    "03354": "Nottingham",
    "03462": "Peterborough",
    "03534": "Birmingham",
    "03827": "Plymouth",
    "03839": "Exeter",
    "03726": "Bristol",
    "03779": "London",
    "03876": "Brighton",
    "03801": "Canterbury"
}

all_records = []

for station_id, station_name in STATIONS.items():
    response = requests.get(
        "https://meteostat.p.rapidapi.com/stations/monthly",
        headers=HEADERS,
        params={"station": station_id, "start": "2021-01-01", "end": "2025-12-31"}
    )
    data = response.json().get("data", [])

    for row in data:
        row["station_id"]   = station_id
        row["station_name"] = station_name
        all_records.append(row)

    print(f"✅ {station_name}: {len(data)} months fetched")
    time.sleep(0.3)

df = pd.DataFrame(all_records)

print(df)
df.to_csv("England_weather.csv", index=False)
# Out:
# ✅ Newcastle upon Tyne: 60 months fetched
# ✅ Sunderland: 60 months fetched
# ✅ Middlesbrough: 60 months fetched
# ✅ Leeds: 60 months fetched
# ✅ Manchester: 60 months fetched
# ✅ York: 60 months fetched
# ✅ Nottingham: 60 months fetched
# ✅ Peterborough: 60 months fetched
# ✅ Birmingham: 60 months fetched
# ✅ Plymouth: 60 months fetched
# ✅ Exeter: 60 months fetched
# ✅ Bristol: 60 months fetched
# ✅ London: 60 months fetched
# ✅ Brighton: 60 months fetched
# ✅ Canterbury: 60 months fetched
#                     date  tavg  tmin  tmax  prcp  wspd    pres  tsun  \
# 0    2021-01-01 00:00:00   2.2   0.6   3.7   NaN  None  1009.4   NaN
# 1    2021-02-01 00:00:00   3.9   2.0   6.1   NaN  None  1013.1   NaN
# 2    2021-03-01 00:00:00   6.3   3.6   9.2   NaN  None  1017.8   NaN
# 3    2021-04-01 00:00:00   5.0   1.1   8.8   NaN  None  1023.8   NaN
# 4    2021-05-01 00:00:00   8.6   5.1  11.9   NaN  None  1008.0   NaN
# ..                   ...   ...   ...   ...   ...   ...     ...   ...
# 895  2025-08-01 00:00:00  18.3  14.9  21.9  20.1  None  1016.5   NaN
# 896  2025-09-01 00:00:00  15.4  12.4  18.4  55.1  None  1015.2   NaN
# 897  2025-10-01 00:00:00  12.6  10.0  15.2  69.0  None  1014.3   NaN
# 898  2025-11-01 00:00:00   9.7   7.1  11.8  68.7  None  1010.3   NaN
# 899  2025-12-01 00:00:00   8.0   6.0   9.8  49.7  None  1015.8   NaN
#
#     station_id         station_name
# 0        03245  Newcastle upon Tyne
# 1        03245  Newcastle upon Tyne
# 2        03245  Newcastle upon Tyne
# 3        03245  Newcastle upon Tyne
# 4        03245  Newcastle upon Tyne
# ..         ...                  ...
# 895      03801           Canterbury
# 896      03801           Canterbury
# 897      03801           Canterbury
# 898      03801           Canterbury
# 899      03801           Canterbury
#
# [900 rows x 10 columns]
